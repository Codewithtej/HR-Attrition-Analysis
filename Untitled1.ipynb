# %%
import pandas as pd
import sklearn 
import seaborn as sns
import statistics
import matplotlib.pyplot as plt
import numpy as np

# %%
data= pd.read_csv('C:/Users/sairaghu.t/OneDrive - Ugam Solutions SEZ Pvt.Ltd/Documents/capestone project/data_set_1_capstone_csv.csv')

# %%
data.head(100)
# Out:
#     Last_promotion_gsp  Years@Current Mangers      Education   EducationField  \
# 0                    0                      2         Master  Human Resources
# 1                    2                      2         Master  Human Resources
# 2                    4                      4       Bachelor  Human Resources
# 3                    4                      7       Bachelor  Human Resources
# 4                    1                      0       Bachelor  Human Resources
# 5                    0                      2       Bachelor  Human Resources
# 6                   12                      6         Master  Human Resources
# 7                    2                     10       Bachelor  Human Resources
# 8                    3                      6       Bachelor  Human Resources
# 9                    0                      4       Bachelor  Human Resources
# 10                   0                      2        College  Human Resources
# 11                   0                      3        College  Human Resources
# 12                   5                      0       Bachelor  Human Resources
# 13                   1                      4       Bachelor  Human Resources
# 14                   0                      9       Bachelor  Human Resources
# 15                   1                      2         Master  Human Resources
# 16                   0                      2            Phd  Human Resources
# 17                   0                      0  Below College  Human Resources
# 18                   1                      2       Bachelor  Human Resources
# 19                   1                      2       Bachelor  Human Resources
# 20                   3                      8       Bachelor  Human Resources
# 21                   0                      0            Phd  Human Resources
# 22                   2                      0       Bachelor  Human Resources
# 23                   0                      8  Below College  Human Resources
# 24                   0                      0       Bachelor  Human Resources
# 25                   1                      4         Master  Human Resources
# 26                   1                      2       Bachelor  Human Resources
# 27                   1                      2         Master  Human Resources
# 28                   3                      2         Master  Human Resources
# 29                   5                      4       Bachelor  Human Resources
# ..                 ...                    ...            ...              ...
# 70                   6                      7  Below College    Life Sciences
# 71                   0                      0         Master    Life Sciences
# 72                   1                      3       Bachelor    Life Sciences
# 73                   0                      0         Master    Life Sciences
# 74                   0                      1       Bachelor    Life Sciences
# 75                   1                      7       Bachelor    Life Sciences
# 76                   0                      0        College    Life Sciences
# 77                   0                      1  Below College    Life Sciences
# 78                   0                      0        College    Life Sciences
# 79                   8                     12        College    Life Sciences
# 80                   1                      8            Phd    Life Sciences
# 81                   1                      7         Master    Life Sciences
# 82                   0                      7         Master    Life Sciences
# 83                   9                      9            Phd    Life Sciences
# 84                   7                      9       Bachelor    Life Sciences
# 85                   0                      3       Bachelor    Life Sciences
# 86                   0                      0       Bachelor    Life Sciences
# 87                   1                      3  Below College    Life Sciences
# 88                   0                      4       Bachelor    Life Sciences
# 89                   0                      9       Bachelor    Life Sciences
# 90                   0                      0       Bachelor    Life Sciences
# 91                   1                      8         Master    Life Sciences
# 92                   3                      0  Below College    Life Sciences
# 93                   1                      0        College    Life Sciences
# 94                   0                      2       Bachelor    Life Sciences
# 95                   0                      3         Master    Life Sciences
# 96                  10                      8       Bachelor    Life Sciences
# 97                  11                     11         Master    Life Sciences
# 98                   0                      0  Below College    Life Sciences
# 99                   1                      0       Bachelor    Life Sciences
#
#     Employee_ID  Env_Satisfaction  Gender  HourlyRate  Job_Involvement  \
# ..       ...    ...                    ...                  ...
# 70         1    ...                      0                   10
# 71         1    ...                      1                    6
# 72         2    ...                      2                   10
# 73         1    ...                      1                    1
# 74         1    ...                      0                    1
# 75         3    ...                      0                    9
# 76         1    ...                      0                    8
# 77         1    ...                      0                    1
# 78         3    ...                      0                   23
# 79         3    ...                      0                   15
# 80         3    ...                      1                    9
# 81         2    ...                      1                   10
# 82         2    ...                      1                    7
# 83         2    ...                      0                   10
# 84         3    ...                      0                   28
# 85         2    ...                      0                    6
# 86         3    ...                      1                   25
# 87         2    ...                      0                   20
# 88         1    ...                      1                    6
# 89         2    ...                      2                   10
# 90         1    ...                      0                    5
# 91         2    ...                      0                   11
# 92         2    ...                      2                   10
# 93         3    ...                      1                   24
# 94         3    ...                      0                   37
# 95         1    ...                      2                   10
# 96         2    ...                      3                   11
# 97         4    ...                      1                   22
# 98         1    ...                      0                    1
# 99         1    ...                      0                    1
#
#    Training time spent  Work LifeBalance  Years @company Years@Current role  \
# 0                    3               3.0               3                  2
# 1                    3               3.0               3                  2
# 2                    3               3.0               5                  3
# 3                    2               1.0              11                  9
# 4                    1               3.0               2                  2
# 5                    2               3.0               3                  2
# 6                    2               2.0              21                  6
# 7                    3               3.0              22                  7
# 8                    3               1.0               8                  3
# 9                    2               3.0               5                  2
# 10                   1               1.0               3                  2
# 11                   4               4.0               4                  3
# 12                   2               4.0               7                  6
# 13                   2               3.0               5                  4
# 14                   5               3.0              20                  7
# 15                   2               3.0               6                  3
# 16                   3               3.0              10                  7
# 17                   2               3.0               1                  0
# 18                   4               3.0               3                  2
# 19                   0               2.0               4                  2
# 20                   3               3.0              11                 10
# 21                   4               3.0               1                  0
# 22                   3               3.0               2                  2
# 23                   2               2.0              10                  1
# 24                   2               3.0               1                  0
# 25                   0               3.0              10                  9
# 26                   3               3.0               2                  0
# 27                   2               3.0               3                  2
# 28                   2               3.0               3                  2
# 29                   2               3.0               5                  3
# ..                 ...               ...             ...                ...
# 70                   5               3.0              10                  2
# 71                   3               4.0               1                  1
# 72                   3               3.0               5                  3
# 73                   6               3.0               1                  0
# 74                   2               2.0               1                  0
# 75                   0               3.0               9                  8
# 76                   1               3.0               1                  0
# 77                   2               3.0               1                  0
# 78                   2               3.0               1                  0
# 79                   1               3.0              15                 14
# 80                   3               2.0               9                  8
# 81                   3               2.0               7                  7
# 82                   2               4.0               7                  5
# 83                   2               3.0              10                  3
# 84                   3               2.0              21                 16
# 85                   3               3.0               6                  5
# 86                   2               3.0               1                  0
# 87                   2               2.0               4                  3
# 88                   3               3.0               5                  4
# 89                   3               3.0              10                  4
# 90                   3               3.0               1                  0
# 91                   2               3.0              11                  7
# 92                   1               2.0              10                  8
# 93                   4               3.0               1                  0
# 94                   3               2.0               6                  4
# 95                   4               3.0               4                  2
# 96                   3               3.0              11                 10
# 97                   3               2.0              22                  3
# 98                   2               3.0               1                  0
# 99                   5               3.0               1                  0
#
#        BusinessTravel                    Dept  Travel_distance  Attrition
.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2940 entries, 0 to 2939
# Data columns (total 31 columns):
# Last_promotion_gsp            2940 non-null int64
# Years@Current Mangers         2940 non-null int64
# Education                     2940 non-null object
# EducationField                2940 non-null object
# Employee_ID                   2940 non-null int64
# Env_Satisfaction              2940 non-null int64
# Gender                        2940 non-null object
# HourlyRate                    2940 non-null int64
# Job_Involvement               2940 non-null int64
# JobLevel                      2940 non-null int64
# JobRole                       2940 non-null object
# Job satisfac                  2940 non-null int64
# Marital Status                2940 non-null object
# Monthly Income                2940 non-null int64
# Company Changed               2940 non-null int64
# 18Yrs                         2940 non-null object
# Over Time                     2940 non-null object
# PercentSalaryHike             2940 non-null int64
# Performance Rating            2940 non-null int64
# Relationship Satisfaction     2940 non-null int64
# Standard Hours                2940 non-null int64
# Stock Option Level            2940 non-null int64
# Total Working Years           2940 non-null int64
# Training time spent           2940 non-null int64
# Work LifeBalance              2891 non-null float64
# Years @company                2940 non-null int64
# Years@Current role            2940 non-null int64
# BusinessTravel                2940 non-null object
# Dept                          2940 non-null object
# Travel_distance               2940 non-null int64
# Attrition                     2940 non-null object
# dtypes: float64(1), int64(20), object(10)
# memory usage: 712.1+ KB
# (2940, 31)

# %%
cols_with_missing = [col for col in data.columns
                     if data[col].isnull().any()]
print(cols_with_missing)
# Out:
# ['Work LifeBalance']

# %%
data['Work LifeBalance'].isnull().sum()
# Out:
# 49

# %%
from sklearn.impute import SimpleImputer

# Imputation
my_imputer = SimpleImputer()
imputed_data = pd.DataFrame(my_imputer.fit_transform(data[cols_with_missing]))
data[cols_with_missing] = imputed_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-24-099464b4e232> in <module>()
# ----> 1 from sklearn.impute import SimpleImputer
#       2
#       3 # Imputation
#       4 my_imputer = SimpleImputer()
#       5 imputed_data = pd.DataFrame(my_imputer.fit_transform(data[cols_with_missing]))
#
# ImportError: No module named 'sklearn.impute'

# %%
# Get list of categorical variables
s = (data.dtypes == 'object')
object_cols = list(s[s].index)

print("Categorical variables:")
print(object_cols)
# Out:
# Categorical variables:
# ['Education', 'EducationField', 'Gender', 'JobRole', 'Marital Status', '18Yrs', 'Over Time', 'BusinessTravel', 'Dept', 'Attrition']

# %%
def with_hue(plot, feature, Number_of_categories, hue_categories):
    a = [p.get_height() for p in plot.patches]
    patch = [p for p in plot.patches]
    for i in range(Number_of_categories):
        total = feature.value_counts().values[i]
        for j in range(hue_categories):
            percentage = '{:.1f}%'.format(100 * a[(j*Number_of_categories + i)]/total)
            x = patch[(j*Number_of_categories + i)].get_x() + patch[(j*Number_of_categories + i)].get_width() / 2 - 0.15
            y = patch[(j*Number_of_categories + i)].get_y() + patch[(j*Number_of_categories + i)].get_height() 
            ax.annotate(percentage, (x, y), size = 12)
    plt.show()

def without_hue(plot, feature):
    total = len(feature)
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() / 2 - 0.05
        y = p.get_y() + p.get_height()
        ax.annotate(percentage, (x, y), size = 12)
    plt.show()

# %%
plt.figure(figsize=(7,5))
ax=sns.countplot('Attrition',data=data)
plt.xticks(size=12)
plt.xlabel('Attrition',size=12)
plt.yticks(size=12)
plt.ylabel('Count',size=12)
ax.set_title('Attrition Breakdown')
without_hue(ax,data.Attrition)
plt.savefig("Attrition.jpg")
plt.show()
